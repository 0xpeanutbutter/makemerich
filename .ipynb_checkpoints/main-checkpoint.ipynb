# %% [markdown]
# ## Reading the Yahoo stocks and necessary stuff
#
# ### Stock data is imported from yfinance

# %%
#importing stuff
# !pip3 install yfinance
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Collecting yfinance
#   Using cached yfinance-0.1.55.tar.gz (23 kB)
# Requirement already satisfied: pandas>=0.24 in /home/omar/anaconda3/lib/python3.8/site-packages (from yfinance) (1.1.3)
# Requirement already satisfied: numpy>=1.15 in /home/omar/anaconda3/lib/python3.8/site-packages (from yfinance) (1.19.2)
# Requirement already satisfied: requests>=2.20 in /home/omar/.local/lib/python3.8/site-packages (from yfinance) (2.24.0)
# Collecting multitasking>=0.0.7
#   Using cached multitasking-0.0.9.tar.gz (8.1 kB)
# Requirement already satisfied: lxml>=4.5.1 in /home/omar/anaconda3/lib/python3.8/site-packages (from yfinance) (4.6.1)
# Requirement already satisfied: pytz>=2017.2 in /home/omar/anaconda3/lib/python3.8/site-packages (from pandas>=0.24->yfinance) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/omar/anaconda3/lib/python3.8/site-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/omar/anaconda3/lib/python3.8/site-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/omar/.local/lib/python3.8/site-packages (from requests>=2.20->yfinance) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /home/omar/.local/lib/python3.8/site-packages (from requests>=2.20->yfinance) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/omar/.local/lib/python3.8/site-packages (from requests>=2.20->yfinance) (1.25.10)
# Requirement already satisfied: six>=1.5 in /home/omar/.local/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)
# Building wheels for collected packages: yfinance, multitasking
#   Building wheel for yfinance (setup.py) ... done
#   Created wheel for yfinance: filename=yfinance-0.1.55-py2.py3-none-any.whl size=22618 sha256=f2a34e9eb56b099a25f850f3d29e188ad4832da6540337a606c8040e9311fabd
#   Stored in directory: /home/omar/.cache/pip/wheels/b4/c3/39/9c01ae2b4726f37024bba5592bec868b47a2fab5a786e8979a
#   Building wheel for multitasking (setup.py) ... done
#   Created wheel for multitasking: filename=multitasking-0.0.9-py3-none-any.whl size=8367 sha256=4e3fe86e36ea119cfc2144f430e1ac6cfe6dc8185c21abca109d1fb597a1252e
#   Stored in directory: /home/omar/.cache/pip/wheels/57/6d/a3/a39b839cc75274d2acfb1c58bfead2f726c6577fe8c4723f13
# Successfully built yfinance multitasking
# Installing collected packages: multitasking, yfinance
# Successfully installed multitasking-0.0.9 yfinance-0.1.55
# WARNING: You are using pip version 20.1.1; however, version 21.0.1 is available.
# You should consider upgrading via the '/home/omar/anaconda3/bin/python -m pip install --upgrade pip' command.
# Matplotlib is building the font cache; this may take a moment.

# %%
#getting data
data = yf.download('AAPL', start="2020-01-31", end="2021-01-31")
data.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-25  143.070007  145.089996  136.539993  142.919998  142.706757
# 2021-01-26  143.600006  144.300003  141.369995  143.160004  142.946396
# 2021-01-27  143.429993  144.300003  140.410004  142.059998  141.848038
# 2021-01-28  139.520004  141.990005  136.699997  137.089996  136.885452
# 2021-01-29  135.830002  136.740005  130.210007  131.960007  131.763107
#
#                Volume
# Date
# 2021-01-25  157611700
# 2021-01-26   98390600
# 2021-01-27  140843800
# 2021-01-28  142621100
# 2021-01-29  177180600

# %%
fig = plt.figure(figsize = (10,5))
data['Close'].plot(figsize=(10,5))
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-21e58150968e> in <module>
# ----> 1 fig = plt.figure(figsize = (10,5))
#       2 data['Close'].plot(figsize=(10,5))
#       3 plt.legend()
#       4 jt -r
#
# NameError: name 'plt' is not defined

# %%
data['Open'].plot(figsize = (10,5))
plt.legend()

# %% [markdown]
# # Moving Averages
#
# ## Exponential Moving Average
#
# ### EMA = (Closing price - EMA*(previous day)) x multiplier  +  EMA*(previous day)
# ### Weightage multiplier = 2 / (moving average period +1)

# %% [markdown]
# ## Moving Average Convergence Divergence (MACD)
#
# ### In MACD we use two series, MACD series which is the difference between the 26-day EMA and 12-day EMA and signal series which is the 9 day EMA of MACD series.
# ### When the MACD line crosses above the signal line, then it is recommended to buy the underlying security.
# ### When the MACD line crosses below the signal line, then a signal to sell is triggered.

# %%
data['12D_EMA'] = data.Close.ewm(span = 12, adjust = False).mean()
data['26D_EMA'] = data.Close.ewm(span= 26, adjust = False).mean()
data['MACD'] = data['12D_EMA'] - data['26D_EMA']

data[['Close','12D_EMA','26D_EMA']].plot(figsize=(10,5))
plt.show()

# %%
data['MACD'].plot(figsize=(10,5))
plt.show()

# %%
data['MacdSignal'] = data.MACD.ewm(span=9,adjust = False).mean()
data['MacdSignal'].plot(figsize=(10,5))
plt.show()

# %% [markdown]
# ### When the value of MACD series is greater than signal series then buy, else sell.

# %%
data['TradingSignal'] = np.where(data['MACD'] > data['MacdSignal'], 1, -1)
data['TradingSignal'].plot(figsize=(10,5))
plt.show()
